# %%
import pandas as pd
df = pd.read_csv("anki_fixed.txt",sep=";")
df.head()
# Out:
#     凄い    すごい                  great, incredible        Adjective
# 0   親切   しんせつ                  kind, kindhearted  Adjectival Noun
# 1   絶対   ぜったい                  absolutely, never           Adverb
# 2   先月   せんげつ                         last month             Noun
# 3  一昨年   おととし  the year before last (colloquial)             Noun
# 4  冬休み  ふゆやすみ                    winter vacation             Noun

# %%
output  = ""
with open("anki_2.txt") as f:
    lines = f.readlines()
    for line in lines:
        output+= ";".join(line.split("\t")[1:5]) + "\n" 
with open("anki_fixed.txt","w") as f:
    f.write(output)
